# %% [markdown]
# # Exploratory Data Analysis

# %%
# !pip install pandas_profiling
# !pip install sweetviz
# Out:
# Requirement already satisfied: pandas_profiling in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (2.7.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (1.21.5)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (0.2.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (2.27.1)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (3.5.1)
# Requirement already satisfied: astropy>=4.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (5.0.4)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (2.11.3)
# Requirement already satisfied: joblib in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (1.2.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (1.4.2)
# Requirement already satisfied: phik>=0.9.10 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (0.12.2)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (4.64.0)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (0.4.2)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (0.1.12)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (1.7.3)
# Requirement already satisfied: confuse>=1.0.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (2.0.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (7.6.5)
# Requirement already satisfied: visions[type_image_path]==0.4.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas_profiling) (0.4.1)
# Requirement already satisfied: networkx>=2.4 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.1->pandas_profiling) (2.7.1)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.1->pandas_profiling) (21.4.0)
# Requirement already satisfied: imagehash in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.1->pandas_profiling) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.1->pandas_profiling) (9.0.1)
# Requirement already satisfied: pyerfa>=2.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from astropy>=4.0->pandas_profiling) (2.0.0)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from astropy>=4.0->pandas_profiling) (6.0)
# Requirement already satisfied: packaging>=19.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from astropy>=4.0->pandas_profiling) (21.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_profiling) (6.9.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_profiling) (8.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_profiling) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_profiling) (5.3.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_profiling) (1.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_profiling) (5.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_profiling) (0.2.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (0.1.2)
# Requirement already satisfied: nest-asyncio in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (1.5.5)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (6.1.12)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (1.5.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (2.11.2)
# Requirement already satisfied: stack-data in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.2.0)
# Requirement already satisfied: colorama in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.4.6)
# Requirement already satisfied: pickleshare in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (61.2.0)
# Requirement already satisfied: backcall in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.2.0)
# Requirement already satisfied: decorator in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from jinja2>=2.11.1->pandas_profiling) (2.0.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (302)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (0.11.0)
# Requirement already satisfied: seaborn in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from missingno>=0.4.2->pandas_profiling) (0.11.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_profiling) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_profiling) (2.15.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_profiling) (0.18.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->pandas_profiling) (2021.3)
# Requirement already satisfied: wcwidth in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_profiling) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from requests>=2.23.0->pandas_profiling) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from requests>=2.23.0->pandas_profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from requests>=2.23.0->pandas_profiling) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from requests>=2.23.0->pandas_profiling) (2021.10.8)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (6.4.8)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (21.3.0)
# Requirement already satisfied: nbconvert in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (6.4.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (1.8.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (2.21)
# Requirement already satisfied: PyWavelets in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.4.1->pandas_profiling) (1.3.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.5.13)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.4)
# Requirement already satisfied: defusedxml in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.1.2)
# Requirement already satisfied: testpath in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.5.0)
# Requirement already satisfied: bleach in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.8.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_profiling) (0.5.1)
# Requirement already satisfied: executing in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_profiling) (0.2.2)
# Requirement already satisfied: sweetviz in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from sweetviz) (4.64.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from sweetviz) (1.7.3)
# Requirement already satisfied: importlib-resources>=1.2.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from sweetviz) (5.10.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from sweetviz) (1.21.5)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from sweetviz) (3.5.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from sweetviz) (2.11.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from sweetviz) (1.4.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from importlib-resources>=1.2.0->sweetviz) (3.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Requirement already satisfied: colorama in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)

# %%
#load the libraries
import pandas as pd
import numpy as np
import pandas_profiling as pp
import sweetviz as sv

# %%
br = pd.read_csv(r"BERGER PAINTS.csv")

# %%
br
# Out:
#                   Date  Open Price  High Price  Low Price  Close Price  \
# 0         1-March-2023      584.95      585.00     575.75       580.85
# 1     28-February-2023      550.05      582.60     550.05       580.20
# 2     27-February-2023      553.05      559.10     550.00       557.20
# 3     24-February-2023      556.15      569.85     552.30       558.40
# 4     23-February-2023      567.25      567.25     552.60       560.50
# ...                ...         ...         ...        ...          ...
# 2470      7-March-2013      195.00      196.00     190.70       194.40
# 2471      6-March-2013      191.00      196.70     188.40       191.05
# 2472      5-March-2013      191.20      194.00     189.10       189.70
# 2473      4-March-2013      193.30      193.30     186.55       189.40
# 2474      1-March-2013      194.00      197.00     190.00       192.40
#
#              WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0     581.247581         54560           3452            31712868.0
# 1     571.598180         81860           4770            46791027.0
# 2     554.498412         33372           3086            18504721.0
# 3     560.124837         29975           1310            16789742.0
# 4     558.820772         33700           3220            18832260.0
# ...          ...           ...            ...                   ...
# 2470  193.892632         40254            962             7804954.0
# 2471  192.457812         89943           2130            17310233.0
# 2472  190.657514         28661           1005             5464435.0
# 2473  189.351339         34471           1395             6527130.0
# 2474  194.197707         51814           1396            10062160.0
#
#       Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  24120.0                      44.21             9.25
# 1                  44717.0                      54.63            32.55
# 2                  16201.0                      48.55             9.10
# 3                  18213.0                      60.76            17.55
# 4                  10329.0                      30.65            14.65
# ...                    ...                        ...              ...
# 2470               11390.0                      28.30             5.30
# 2471               15923.0                      17.70             8.30
# 2472                6820.0                      23.80             4.90
# 2473                6454.0                      18.72             6.75
# 2474               10022.0                      19.34             7.00
#
#       Spread Close-Open
# 0                 -4.10
# 1                 30.15
# 2                  4.15
# 3                  2.25
# 4                 -6.75
# ...                 ...
# 2470              -0.60
# 2471               0.05
# 2472              -1.50
# 2473              -3.90
# 2474              -1.60
#
# [2475 rows x 13 columns]

# %%
br1=br.iloc[::-1].reset_index(drop=True)
br1
# Out:
#                   Date  Open Price  High Price  Low Price  Close Price  \
# 0         1-March-2013      194.00      197.00     190.00       192.40
# 1         4-March-2013      193.30      193.30     186.55       189.40
# 2         5-March-2013      191.20      194.00     189.10       189.70
# 3         6-March-2013      191.00      196.70     188.40       191.05
# 4         7-March-2013      195.00      196.00     190.70       194.40
# ...                ...         ...         ...        ...          ...
# 2470  23-February-2023      567.25      567.25     552.60       560.50
# 2471  24-February-2023      556.15      569.85     552.30       558.40
# 2472  27-February-2023      553.05      559.10     550.00       557.20
# 2473  28-February-2023      550.05      582.60     550.05       580.20
# 2474      1-March-2023      584.95      585.00     575.75       580.85
#
#              WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0     194.197707         51814           1396            10062160.0
# 1     189.351339         34471           1395             6527130.0
# 2     190.657514         28661           1005             5464435.0
# 3     192.457812         89943           2130            17310233.0
# 4     193.892632         40254            962             7804954.0
# ...          ...           ...            ...                   ...
# 2470  558.820772         33700           3220            18832260.0
# 2471  560.124837         29975           1310            16789742.0
# 2472  554.498412         33372           3086            18504721.0
# 2473  571.598180         81860           4770            46791027.0
# 2474  581.247581         54560           3452            31712868.0
#
#       Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  10022.0                      19.34             7.00
# 1                   6454.0                      18.72             6.75
# 2                   6820.0                      23.80             4.90
# 3                  15923.0                      17.70             8.30
# 4                  11390.0                      28.30             5.30
# ...                    ...                        ...              ...
# 2470               10329.0                      30.65            14.65
# 2471               18213.0                      60.76            17.55
# 2472               16201.0                      48.55             9.10
# 2473               44717.0                      54.63            32.55
# 2474               24120.0                      44.21             9.25
#
#       Spread Close-Open
# 0                 -1.60
# 1                 -3.90
# 2                 -1.50
# 3                  0.05
# 4                 -0.60
# ...                 ...
# 2470              -6.75
# 2471               2.25
# 2472               4.15
# 2473              30.15
# 2474              -4.10
#
# [2475 rows x 13 columns]

# %%
br1["Date"]=pd.to_datetime(br1["Date"])
br1
# Out:
#            Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0    2013-03-01      194.00      197.00     190.00       192.40  194.197707
# 1    2013-03-04      193.30      193.30     186.55       189.40  189.351339
# 2    2013-03-05      191.20      194.00     189.10       189.70  190.657514
# 3    2013-03-06      191.00      196.70     188.40       191.05  192.457812
# 4    2013-03-07      195.00      196.00     190.70       194.40  193.892632
# ...         ...         ...         ...        ...          ...         ...
# 2470 2023-02-23      567.25      567.25     552.60       560.50  558.820772
# 2471 2023-02-24      556.15      569.85     552.30       558.40  560.124837
# 2472 2023-02-27      553.05      559.10     550.00       557.20  554.498412
# 2473 2023-02-28      550.05      582.60     550.05       580.20  571.598180
# 2474 2023-03-01      584.95      585.00     575.75       580.85  581.247581
#
#       No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0            51814           1396            10062160.0               10022.0
# 1            34471           1395             6527130.0                6454.0
# 2            28661           1005             5464435.0                6820.0
# 3            89943           2130            17310233.0               15923.0
# 4            40254            962             7804954.0               11390.0
# ...            ...            ...                   ...                   ...
# 2470         33700           3220            18832260.0               10329.0
# 2471         29975           1310            16789742.0               18213.0
# 2472         33372           3086            18504721.0               16201.0
# 2473         81860           4770            46791027.0               44717.0
# 2474         54560           3452            31712868.0               24120.0
#
#       % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# 0                         19.34             7.00              -1.60
# 1                         18.72             6.75              -3.90
# 2                         23.80             4.90              -1.50
# 3                         17.70             8.30               0.05
# 4                         28.30             5.30              -0.60
# ...                         ...              ...                ...
# 2470                      30.65            14.65              -6.75
# 2471                      60.76            17.55               2.25
# 2472                      48.55             9.10               4.15
# 2473                      54.63            32.55              30.15
# 2474                      44.21             9.25              -4.10
#
# [2475 rows x 13 columns]

# %%
#creating columns day,month,year for visualization purpose
br1["day"]=br1["Date"].dt.strftime("%d")
br1["month"]=br1["Date"].dt.strftime("%b")
br1["year"]=br1["Date"].dt.strftime("%y")

# %%
br1
# Out:
#            Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0    2013-03-01      194.00      197.00     190.00       192.40  194.197707
# 1    2013-03-04      193.30      193.30     186.55       189.40  189.351339
# 2    2013-03-05      191.20      194.00     189.10       189.70  190.657514
# 3    2013-03-06      191.00      196.70     188.40       191.05  192.457812
# 4    2013-03-07      195.00      196.00     190.70       194.40  193.892632
# ...         ...         ...         ...        ...          ...         ...
# 2470 2023-02-23      567.25      567.25     552.60       560.50  558.820772
# 2471 2023-02-24      556.15      569.85     552.30       558.40  560.124837
# 2472 2023-02-27      553.05      559.10     550.00       557.20  554.498412
# 2473 2023-02-28      550.05      582.60     550.05       580.20  571.598180
# 2474 2023-03-01      584.95      585.00     575.75       580.85  581.247581
#
#       No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0            51814           1396            10062160.0               10022.0
# 1            34471           1395             6527130.0                6454.0
# 2            28661           1005             5464435.0                6820.0
# 3            89943           2130            17310233.0               15923.0
# 4            40254            962             7804954.0               11390.0
# ...            ...            ...                   ...                   ...
# 2470         33700           3220            18832260.0               10329.0
# 2471         29975           1310            16789742.0               18213.0
# 2472         33372           3086            18504721.0               16201.0
# 2473         81860           4770            46791027.0               44717.0
# 2474         54560           3452            31712868.0               24120.0
#
#       % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open day month  \
# 0                         19.34             7.00              -1.60  01   Mar
# 1                         18.72             6.75              -3.90  04   Mar
# 2                         23.80             4.90              -1.50  05   Mar
# 3                         17.70             8.30               0.05  06   Mar
# 4                         28.30             5.30              -0.60  07   Mar
# ...                         ...              ...                ...  ..   ...
# 2470                      30.65            14.65              -6.75  23   Feb
# 2471                      60.76            17.55               2.25  24   Feb
# 2472                      48.55             9.10               4.15  27   Feb
# 2473                      54.63            32.55              30.15  28   Feb
# 2474                      44.21             9.25              -4.10  01   Mar
#
#      year
# 0      13
# 1      13
# 2      13
# 3      13
# 4      13
# ...   ...
# 2470   23
# 2471   23
# 2472   23
# 2473   23
# 2474   23
#
# [2475 rows x 16 columns]

# %%
br1.tail(10)
# Out:
#            Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 2465 2023-02-16      558.35      563.45     555.60       562.15  560.626496
# 2466 2023-02-17      564.90      569.75     561.35       568.90  566.243265
# 2467 2023-02-20      573.30      573.30     563.65       570.40  567.649928
# 2468 2023-02-21      569.15      573.80     564.10       570.65  569.234856
# 2469 2023-02-22      560.05      570.15     560.05       566.65  563.405617
# 2470 2023-02-23      567.25      567.25     552.60       560.50  558.820772
# 2471 2023-02-24      556.15      569.85     552.30       558.40  560.124837
# 2472 2023-02-27      553.05      559.10     550.00       557.20  554.498412
# 2473 2023-02-28      550.05      582.60     550.05       580.20  571.598180
# 2474 2023-03-01      584.95      585.00     575.75       580.85  581.247581
#
#       No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 2465          9858            872             5526656.0                3940.0
# 2466         12250            940             6936480.0                5565.0
# 2467         16011           1038             9088643.0                6482.0
# 2468         39207           2142            22317991.0               26439.0
# 2469         40018           2920            22546366.0               17673.0
# 2470         33700           3220            18832260.0               10329.0
# 2471         29975           1310            16789742.0               18213.0
# 2472         33372           3086            18504721.0               16201.0
# 2473         81860           4770            46791027.0               44717.0
# 2474         54560           3452            31712868.0               24120.0
#
#       % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open day month  \
# 2465                      39.97             7.85               3.80  16   Feb
# 2466                      45.43             8.40               4.00  17   Feb
# 2467                      40.48             9.65              -2.90  20   Feb
# 2468                      67.43             9.70               1.50  21   Feb
# 2469                      44.16            10.10               6.60  22   Feb
# 2470                      30.65            14.65              -6.75  23   Feb
# 2471                      60.76            17.55               2.25  24   Feb
# 2472                      48.55             9.10               4.15  27   Feb
# 2473                      54.63            32.55              30.15  28   Feb
# 2474                      44.21             9.25              -4.10  01   Mar
#
#      year
# 2465   23
# 2466   23
# 2467   23
# 2468   23
# 2469   23
# 2470   23
# 2471   23
# 2472   23
# 2473   23
# 2474   23

# %%
br1.head(10)
# Out:
#         Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0 2013-03-01       194.0      197.00     190.00       192.40  194.197707
# 1 2013-03-04       193.3      193.30     186.55       189.40  189.351339
# 2 2013-03-05       191.2      194.00     189.10       189.70  190.657514
# 3 2013-03-06       191.0      196.70     188.40       191.05  192.457812
# 4 2013-03-07       195.0      196.00     190.70       194.40  193.892632
# 5 2013-03-08       197.6      203.90     195.90       201.50  201.374078
# 6 2013-03-11       203.5      210.45     202.50       206.85  207.780317
# 7 2013-03-12       210.0      212.75     196.30       198.80  205.669714
# 8 2013-03-13       198.0      199.75     192.20       194.00  195.398305
# 9 2013-03-14       194.0      196.30     188.65       192.10  191.778990
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0         51814           1396            10062160.0               10022.0
# 1         34471           1395             6527130.0                6454.0
# 2         28661           1005             5464435.0                6820.0
# 3         89943           2130            17310233.0               15923.0
# 4         40254            962             7804954.0               11390.0
# 5        126952           2794            25564842.0               30341.0
# 6        326698           6403            67881414.0               54738.0
# 7        288371           5399            59309181.0               73354.0
# 8         78337           2222            15306917.0               15409.0
# 9         76897           1997            14747229.0               19625.0
#
#    % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open day month  \
# 0                      19.34             7.00              -1.60  01   Mar
# 1                      18.72             6.75              -3.90  04   Mar
# 2                      23.80             4.90              -1.50  05   Mar
# 3                      17.70             8.30               0.05  06   Mar
# 4                      28.30             5.30              -0.60  07   Mar
# 5                      23.90             8.00               3.90  08   Mar
# 6                      16.75             7.95               3.35  11   Mar
# 7                      25.44            16.45             -11.20  12   Mar
# 8                      19.67             7.55              -4.00  13   Mar
# 9                      25.52             7.65              -1.90  14   Mar
#
#   year
# 0   13
# 1   13
# 2   13
# 3   13
# 4   13
# 5   13
# 6   13
# 7   13
# 8   13
# 9   13

# %% [markdown]
# # Data Structure

# %%
type(br1)
br1.shape
# Out:
# (2475, 16)

# %% [markdown]
# # Data types

# %%
br1.dtypes
# Out:
# Date                         datetime64[ns]
# Open Price                          float64
# High Price                          float64
# Low Price                           float64
# Close Price                         float64
# WAP                                 float64
# No.of Shares                          int64
# No. of Trades                         int64
# Total Turnover (Rs.)                float64
# Deliverable Quantity                float64
# % Deli. Qty to Traded Qty           float64
# Spread High-Low                     float64
# Spread Close-Open                   float64
# day                                  object
# month                                object
# year                                 object
# dtype: object

# %% [markdown]
# # Duplicates

# %%
#Count of duplicated 
br1.duplicated().sum()
# Out:
# 0

# %%
br1
# Out:
#            Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0    2013-03-01      194.00      197.00     190.00       192.40  194.197707
# 1    2013-03-04      193.30      193.30     186.55       189.40  189.351339
# 2    2013-03-05      191.20      194.00     189.10       189.70  190.657514
# 3    2013-03-06      191.00      196.70     188.40       191.05  192.457812
# 4    2013-03-07      195.00      196.00     190.70       194.40  193.892632
# ...         ...         ...         ...        ...          ...         ...
# 2470 2023-02-23      567.25      567.25     552.60       560.50  558.820772
# 2471 2023-02-24      556.15      569.85     552.30       558.40  560.124837
# 2472 2023-02-27      553.05      559.10     550.00       557.20  554.498412
# 2473 2023-02-28      550.05      582.60     550.05       580.20  571.598180
# 2474 2023-03-01      584.95      585.00     575.75       580.85  581.247581
#
#       No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0            51814           1396            10062160.0               10022.0
# 1            34471           1395             6527130.0                6454.0
# 2            28661           1005             5464435.0                6820.0
# 3            89943           2130            17310233.0               15923.0
# 4            40254            962             7804954.0               11390.0
# ...            ...            ...                   ...                   ...
# 2470         33700           3220            18832260.0               10329.0
# 2471         29975           1310            16789742.0               18213.0
# 2472         33372           3086            18504721.0               16201.0
# 2473         81860           4770            46791027.0               44717.0
# 2474         54560           3452            31712868.0               24120.0
#
#       % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open day month  \
# 0                         19.34             7.00              -1.60  01   Mar
# 1                         18.72             6.75              -3.90  04   Mar
# 2                         23.80             4.90              -1.50  05   Mar
# 3                         17.70             8.30               0.05  06   Mar
# 4                         28.30             5.30              -0.60  07   Mar
# ...                         ...              ...                ...  ..   ...
# 2470                      30.65            14.65              -6.75  23   Feb
# 2471                      60.76            17.55               2.25  24   Feb
# 2472                      48.55             9.10               4.15  27   Feb
# 2473                      54.63            32.55              30.15  28   Feb
# 2474                      44.21             9.25              -4.10  01   Mar
#
#      year
# 0      13
# 1      13
# 2      13
# 3      13
# 4      13
# ...   ...
# 2470   23
# 2471   23
# 2472   23
# 2473   23
# 2474   23
#
# [2475 rows x 16 columns]

# %% [markdown]
# # Null values

# %%
br1.isnull().sum()
# Out:
# Date                         0
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         8
# % Deli. Qty to Traded Qty    8
# Spread High-Low              0
# Spread Close-Open            0
# day                          0
# month                        0
# year                         0
# dtype: int64

# %% [markdown]
# # Describe

# %%
br1.describe()
# Out:
#         Open Price   High Price    Low Price  Close Price          WAP  \
# count  2475.000000  2475.000000  2475.000000  2475.000000  2475.000000
# mean    394.056283   399.264202   387.822404   393.178485   393.501871
# std     197.910088   199.698070   195.226444   197.337038   197.333417
# min     175.000000   176.850000   171.050000   173.600000   173.004094
# 25%     237.825000   241.850000   233.625000   237.275000   237.767287
# 50%     296.950000   301.450000   292.000000   296.950000   296.713790
# 75%     564.375000   569.925000   556.425000   563.100000   562.940116
# max     870.000000   872.000000   851.700000   863.650000   859.363128
#
#        No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# count  2.475000e+03    2475.000000          2.475000e+03
# mean   6.855370e+04    1800.220202          2.534436e+07
# std    3.037949e+05    1857.361374          7.940656e+07
# min    2.134000e+03     111.000000          4.465520e+05
# 25%    2.387800e+04     736.500000          7.625916e+06
# 50%    3.877800e+04    1228.000000          1.465309e+07
# 75%    6.842650e+04    2205.500000          2.653086e+07
# max    1.312096e+07   32620.000000          3.044025e+09
#
#        Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# count          2.467000e+03                2467.000000      2475.000000
# mean           3.077366e+04                  34.847021        11.441798
# std            2.838887e+05                  15.403263         8.157269
# min            9.610000e+02                   3.540000         1.550000
# 25%            7.014000e+03                  24.185000         6.150000
# 50%            1.181000e+04                  33.150000         9.200000
# 75%            2.124950e+04                  42.795000        14.175000
# max            1.304344e+07                  99.410000        86.100000
#
#        Spread Close-Open
# count        2475.000000
# mean           -0.877798
# std             8.107676
# min           -71.200000
# 25%            -4.400000
# 50%            -0.850000
# 75%             2.775000
# max            56.300000

# %% [markdown]
# # Data Visulization

# %% [markdown]
# # 1.Box plot

# %%
import seaborn as sns

# Load stock market data
br1 = pd.read_csv(r'BERGER PAINTS.csv')

# Convert 'Date' column to datetime and extract year
br1['Date'] = pd.to_datetime(br1['Date'])
br1['Year'] = br1['Date'].dt.year

# Create box plot of 'Close' column by year using seaborn
sns.boxplot(x='Year', y='Close Price', data=br1)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Close Price'>

# %% [markdown]
# # 2.Line plot

# %%
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='Year',y='Close Price',data=br1)
plt.ylabel('Close Price')
# Out:
# Text(0, 0.5, 'Close Price')

# %% [markdown]
# # 3.RSI plot (Relative Strength Index)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load historical stock price data into a pandas dataframe
br1 = pd.read_csv(r'BERGER PAINTS.csv', index_col='Date', parse_dates=True)

# Define the time period for RSI calculation
period = 14

# Calculate the RSI values using the pandas rolling() function
delta = br1['Close Price'].diff()
gain = delta.where(delta > 0, 0)
loss = -delta.where(delta < 0, 0)
avg_gain = gain.rolling(window=period).mean()
avg_loss = loss.rolling(window=period).mean()
rs = avg_gain / avg_loss
rsi = 100 - (100 / (1 + rs))

# Create a new figure and plot the RSI values
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(br1.index, rsi, label='RSI')

# Add horizontal lines at the overbought and oversold levels
ax.axhline(y=70, color='r', linestyle='--', label='Overbought')
ax.axhline(y=30, color='g', linestyle='--', label='Oversold')

# Add title, legend, and axis labels
ax.set_title('Relative Strength Index')
ax.legend()
ax.set_xlabel('Year')
ax.set_ylabel('RSI')

# Show the plot
plt.show()

# %% [markdown]
# # 4.Candelstick  plot

# %%
pip install mpl_finance
# Out:
# Requirement already satisfied: mpl_finance in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: matplotlib in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from mpl_finance) (3.5.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (9.0.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from matplotlib->mpl_finance) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mpl_finance) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter, WeekdayLocator, DayLocator, MONDAY
from mpl_finance import candlestick_ohlc
import pandas as pd
import numpy as np
# Out:
# C:\Users\Thirumudi Nachiyar\Anaconda3\lib\site-packages\mpl_finance.py:16: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   __warnings.warn('\n\n  ================================================================='+

# %%
# Load data from a CSV file
br1 = pd.read_csv(r'BERGER PAINTS.csv', parse_dates=True, index_col=0)

# Resample the data to weekly intervals
br1 = br1.resample('W').agg({'Open Price': 'first', 'High Price': 'max', 'Low Price': 'min', 'Close Price': 'last'})

# Reset the index to a column
br1 = br1.reset_index()

# Convert the date to the Matplotlib date format
br1['Date'] = br1['Date'].apply(lambda d: d.date())
br1['Date'] = pd.to_datetime(br1['Date'])
br1['Date'] = br1['Date'].apply(lambda d: d.date().toordinal())

# Create a figure and axes instance
fig, ax = plt.subplots()

# Set the x-axis locator to Mondays
mondays = WeekdayLocator(MONDAY)
ax.xaxis.set_major_locator(mondays)

# Format the x-axis dates
date_formatter = DateFormatter('%Y-%m-%d')
ax.xaxis.set_major_formatter(date_formatter)

# Plot the candlestick chart
candlestick_ohlc(ax, br1.values, width=0.6, colorup='g', colordown='r', alpha=1.0)

# Set the axis labels and title
ax.set_xlabel('Date')
ax.set_ylabel('Price')
ax.set_title('Candlestick Chart')

# Show the plot
plt.show()

# %% [markdown]
# # 5.Correlation Heat Map

# %%
#Correlation
br1.corr()
# Out:
#                  Date  Open Price  High Price  Low Price  Close Price
# Date         1.000000    0.830702    0.827773   0.832119     0.831439
# Open Price   0.830702    1.000000    0.998161   0.996262     0.994878
# High Price   0.827773    0.998161    1.000000   0.996186     0.997119
# Low Price    0.832119    0.996262    0.996186   1.000000     0.998334
# Close Price  0.831439    0.994878    0.997119   0.998334     1.000000

# %%
# calculate correlation matrix
corr_matrix = br1.corr()

# plot heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
import seaborn as sns

# %% [markdown]
# # 6.Decompostion plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Generate some sample data
br1 = pd.DataFrame({
    'Date': pd.date_range(start='2010-01-01', end='2021-12-31', freq='M'),
    'value': [i**2 for i in range(144)]
})
br1.set_index('Date', inplace=True)

# Decompose the time series
decomp = seasonal_decompose(br1, model='additive')

# Plot the results
fig, axes = plt.subplots(nrows=4, ncols=1, sharex=True, figsize=(10,10))
plt.subplots_adjust(hspace=0.5)

# Original time series
axes[0].plot(br1.index, br1['value'], label='Original')
axes[0].legend(loc='upper left')

# Trend component
axes[1].plot(br1.index, decomp.trend, label='Trend')
axes[1].legend(loc='upper left')

# Seasonal component
axes[2].plot(br1.index, decomp.seasonal, label='Seasonal')
axes[2].legend(loc='upper left')
# Residual component
axes[3].plot(br1.index, decomp.resid, label='Residual')
axes[3].legend(loc='upper left')

# Set x-axis label
axes[-1].set_xlabel('Year')

plt.show()

# %% [markdown]
# # Stationarity data

# %% [markdown]
# # Kwiatkowski-Phillips-Schmidt-Shin

# %%
import pandas as pd
from statsmodels.tsa.stattools import kpss

# Load the time series data
br1 = pd.read_csv(r'BERGER PAINTS.csv', index_col='Date', parse_dates=True)

# Perform the KPSS test
kpss_stat, p_value, lags, critical_values = kpss(br1['Close Price'])

# Print the results
print('KPSS Statistic:', kpss_stat)
print('p-value:', p_value)
print('Lags Used:', lags)
print('Critical Values:', critical_values)
# Out:
# KPSS Statistic: 6.180432970254543
# p-value: 0.01
# Lags Used: 30
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# C:\Users\Thirumudi Nachiyar\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# If the p-value is greater than 0.05 or the absolute value of the test statistics is less than the critical value,
# we fail to reject H0 and conclude that the time series is stationary.
#
# By KPSS test p-value is less than 0.05 hence the data is still non-stationary.

# %% [markdown]
# # ADF test

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller

# Load time series data into a pandas dataframe
br1 = pd.read_csv(r'BERGER PAINTS.csv', index_col='Date', parse_dates=True)

# Define a function to test stationarity of the data
def test_stationarity(timeseries):
    
    # Calculate rolling statistics
    rolling_mean = timeseries.rolling(window=12).mean()
    rolling_std = timeseries.rolling(window=12).std()

    # Plot rolling statistics
    plt.plot(timeseries, color='blue', label='Original')
    plt.plot(rolling_mean, color='red', label='Rolling Mean')
    plt.plot(rolling_std, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    # Perform the ADF test
    adf_result = adfuller(timeseries, autolag='AIC')

    # Extract and print test results
    print('ADF Test Results:')
    print('Test Statistic: {:.3f}'.format(adf_result[0]))
    print('p-value: {:.3f}'.format(adf_result[1]))
    print('Critical Values:')
    for key, value in adf_result[4].items():
        print('\t{}: {:.3f}'.format(key, value))

    # Interpret test results
    if adf_result[1] <= 0.05:
        print('p-value <= 0.05: The data is stationary.')
    else:
        print('p-value > 0.05: The data is non-stationary.')
        
# Call the function on your time series data
test_stationarity(br1['Close Price'])
# Out:
# ADF Test Results:
# Test Statistic: -1.057
# p-value: 0.732
# Critical Values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567
# p-value > 0.05: The data is non-stationary.

# %%
# Change for (t)th day is Close for (t)th day minus Close for (t-1)th day.
br1['Difference'] = br1['Close Price'].diff()

# Plot the Change
plt.figure(figsize=(10, 7))
plt.plot(br1['Difference'])
plt.title('First Order Differenced Series', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Difference', fontsize=12)
plt.show()

# %%
result = adfuller(br1.Difference.dropna())
print(result)
print('ADF Test Statistic: %.2f' % result[0])
print('5%% Critical Value: %.2f' % result[4]['5%'])
print('p-value: %.2f' % result[1])
# Out:
# (-25.429365843270595, 0.0, 3, 2470, {'1%': -3.4330002465470844, '5%': -2.862710858596359, '10%': -2.567393294431969}, 17591.399165992112)
# ADF Test Statistic: -25.43
# 5% Critical Value: -2.86
# p-value: 0.00

# %% [markdown]
# The p-value is less than 0.05. You reject the null hypothesis and conclude that the time series is stationary.
#
# Thus, the Berger price series was a difference-stationary series. The first-order difference of the Berger price series resulted in a stationary series.

# %% [markdown]
# # Normalize the data

# %%
#Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
br1.values
# Out:
# array([[ 5.8495e+02,  5.8500e+02,  5.7575e+02, ...,  9.2500e+00,
#         -4.1000e+00,         nan],
#        [ 5.5005e+02,  5.8260e+02,  5.5005e+02, ...,  3.2550e+01,
#          3.0150e+01, -6.5000e-01],
#        [ 5.5305e+02,  5.5910e+02,  5.5000e+02, ...,  9.1000e+00,
#          4.1500e+00, -2.3000e+01],
#        ...,
#        [ 1.9120e+02,  1.9400e+02,  1.8910e+02, ...,  4.9000e+00,
#         -1.5000e+00, -1.3500e+00],
#        [ 1.9330e+02,  1.9330e+02,  1.8655e+02, ...,  6.7500e+00,
#         -3.9000e+00, -3.0000e-01],
#        [ 1.9400e+02,  1.9700e+02,  1.9000e+02, ...,  7.0000e+00,
#         -1.6000e+00,  3.0000e+00]])

# %%
array = br1.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array[:,0:5])

#transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[0.59 0.59 0.59 0.59 0.59]
#  [0.54 0.58 0.56 0.59 0.58]
#  [0.54 0.55 0.56 0.56 0.56]
#  [0.55 0.57 0.56 0.56 0.56]
#  [0.56 0.56 0.56 0.56 0.56]]

# %%
import pandas as pd

# Load data into pandas DataFrame
br1 = pd.read_csv(r'BERGER PAINTS.csv')

# Get list of all columns except the date column
cols_to_norm = [col for col in br1.columns if col != 'Date']

# Normalize all non-date columns to be between 0 and 1
br1_norm = (br1[cols_to_norm] - br1[cols_to_norm].min()) / (br1[cols_to_norm].max() - br1[cols_to_norm].min())

# Combine normalized data with date column
br1_norm.insert(0, 'Date', br1['Date'])
 
# Print normalized data
print(br1_norm.head())
# Out:
#                Date  Open Price  High Price  Low Price  Close Price       WAP  \
# 0      1-March-2023    0.589856    0.587139   0.594579     0.590175  0.594796
# 1  28-February-2023    0.539640    0.583687   0.556821     0.589233  0.580737
# 2  27-February-2023    0.543957    0.549881   0.556747     0.555902  0.555823
# 3  24-February-2023    0.548417    0.565346   0.560126     0.557641  0.564021
# 4  23-February-2023    0.564388    0.561605   0.560567     0.560684  0.562121
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0      0.003996       0.102772              0.010273              0.001776
# 1      0.006077       0.143314              0.015227              0.003355
# 2      0.002381       0.091513              0.005933              0.001168
# 3      0.002122       0.036882              0.005370              0.001323
# 4      0.002406       0.095635              0.006041              0.000718
#
#    % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# 0                   0.424220         0.091070           0.526275
# 1                   0.532909         0.366647           0.794902
# 2                   0.469490         0.089296           0.590980
# 3                   0.596850         0.189237           0.576078
# 4                   0.282779         0.154938           0.505490

# %%
br1_norm
# Out:
#                   Date  Open Price  High Price  Low Price  Close Price  \
# 0         1-March-2023    0.589856    0.587139   0.594579     0.590175
# 1     28-February-2023    0.539640    0.583687   0.556821     0.589233
# 2     27-February-2023    0.543957    0.549881   0.556747     0.555902
# 3     24-February-2023    0.548417    0.565346   0.560126     0.557641
# 4     23-February-2023    0.564388    0.561605   0.560567     0.560684
# ...                ...         ...         ...        ...          ...
# 2470      7-March-2013    0.028777    0.027548   0.028869     0.030143
# 2471      6-March-2013    0.023022    0.028555   0.025490     0.025288
# 2472      5-March-2013    0.023309    0.024671   0.026519     0.023332
# 2473      4-March-2013    0.026331    0.023664   0.022772     0.022897
# 2474      1-March-2013    0.027338    0.028987   0.027841     0.027244
#
#            WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0     0.594796      0.003996       0.102772              0.010273
# 1     0.580737      0.006077       0.143314              0.015227
# 2     0.555823      0.002381       0.091513              0.005933
# 3     0.564021      0.002122       0.036882              0.005370
# 4     0.562121      0.002406       0.095635              0.006041
# ...        ...           ...            ...                   ...
# 2470  0.030434      0.002906       0.026177              0.002418
# 2471  0.028343      0.006693       0.062106              0.005541
# 2472  0.025720      0.002022       0.027500              0.001649
# 2473  0.023817      0.002465       0.039497              0.001998
# 2474  0.030878      0.003787       0.039528              0.003159
#
#       Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                 0.001776                   0.424220         0.091070
# 1                 0.003355                   0.532909         0.366647
# 2                 0.001168                   0.469490         0.089296
# 3                 0.001323                   0.596850         0.189237
# 4                 0.000718                   0.282779         0.154938
# ...                    ...                        ...              ...
# 2470              0.000800                   0.258266         0.044352
# 2471              0.001147                   0.147700         0.079834
# 2472              0.000449                   0.211328         0.039622
# 2473              0.000421                   0.158339         0.061502
# 2474              0.000695                   0.164807         0.064459
#
#       Spread Close-Open
# 0              0.526275
# 1              0.794902
# 2              0.590980
# 3              0.576078
# 4              0.505490
# ...                 ...
# 2470           0.553725
# 2471           0.558824
# 2472           0.546667
# 2473           0.527843
# 2474           0.545882
#
# [2475 rows x 13 columns]

# %%
br2_norm=br1_norm.iloc[::-1].reset_index(drop=True)
br2_norm
# Out:
#                   Date  Open Price  High Price  Low Price  Close Price  \
# 0         1-March-2013    0.027338    0.028987   0.027841     0.027244
# 1         4-March-2013    0.026331    0.023664   0.022772     0.022897
# 2         5-March-2013    0.023309    0.024671   0.026519     0.023332
# 3         6-March-2013    0.023022    0.028555   0.025490     0.025288
# 4         7-March-2013    0.028777    0.027548   0.028869     0.030143
# ...                ...         ...         ...        ...          ...
# 2470  23-February-2023    0.564388    0.561605   0.560567     0.560684
# 2471  24-February-2023    0.548417    0.565346   0.560126     0.557641
# 2472  27-February-2023    0.543957    0.549881   0.556747     0.555902
# 2473  28-February-2023    0.539640    0.583687   0.556821     0.589233
# 2474      1-March-2023    0.589856    0.587139   0.594579     0.590175
#
#            WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0     0.030878      0.003787       0.039528              0.003159
# 1     0.023817      0.002465       0.039497              0.001998
# 2     0.025720      0.002022       0.027500              0.001649
# 3     0.028343      0.006693       0.062106              0.005541
# 4     0.030434      0.002906       0.026177              0.002418
# ...        ...           ...            ...                   ...
# 2470  0.562121      0.002406       0.095635              0.006041
# 2471  0.564021      0.002122       0.036882              0.005370
# 2472  0.555823      0.002381       0.091513              0.005933
# 2473  0.580737      0.006077       0.143314              0.015227
# 2474  0.594796      0.003996       0.102772              0.010273
#
#       Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                 0.000695                   0.164807         0.064459
# 1                 0.000421                   0.158339         0.061502
# 2                 0.000449                   0.211328         0.039622
# 3                 0.001147                   0.147700         0.079834
# 4                 0.000800                   0.258266         0.044352
# ...                    ...                        ...              ...
# 2470              0.000718                   0.282779         0.154938
# 2471              0.001323                   0.596850         0.189237
# 2472              0.001168                   0.469490         0.089296
# 2473              0.003355                   0.532909         0.366647
# 2474              0.001776                   0.424220         0.091070
#
#       Spread Close-Open
# 0              0.545882
# 1              0.527843
# 2              0.546667
# 3              0.558824
# 4              0.553725
# ...                 ...
# 2470           0.505490
# 2471           0.576078
# 2472           0.590980
# 2473           0.794902
# 2474           0.526275
#
# [2475 rows x 13 columns]

# %%
br2_norm["Date"]=pd.to_datetime(br2_norm["Date"])
br2_norm
# Out:
#            Date  Open Price  High Price  Low Price  Close Price       WAP  \
# 0    2013-03-01    0.027338    0.028987   0.027841     0.027244  0.030878
# 1    2013-03-04    0.026331    0.023664   0.022772     0.022897  0.023817
# 2    2013-03-05    0.023309    0.024671   0.026519     0.023332  0.025720
# 3    2013-03-06    0.023022    0.028555   0.025490     0.025288  0.028343
# 4    2013-03-07    0.028777    0.027548   0.028869     0.030143  0.030434
# ...         ...         ...         ...        ...          ...       ...
# 2470 2023-02-23    0.564388    0.561605   0.560567     0.560684  0.562121
# 2471 2023-02-24    0.548417    0.565346   0.560126     0.557641  0.564021
# 2472 2023-02-27    0.543957    0.549881   0.556747     0.555902  0.555823
# 2473 2023-02-28    0.539640    0.583687   0.556821     0.589233  0.580737
# 2474 2023-03-01    0.589856    0.587139   0.594579     0.590175  0.594796
#
#       No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0         0.003787       0.039528              0.003159              0.000695
# 1         0.002465       0.039497              0.001998              0.000421
# 2         0.002022       0.027500              0.001649              0.000449
# 3         0.006693       0.062106              0.005541              0.001147
# 4         0.002906       0.026177              0.002418              0.000800
# ...            ...            ...                   ...                   ...
# 2470      0.002406       0.095635              0.006041              0.000718
# 2471      0.002122       0.036882              0.005370              0.001323
# 2472      0.002381       0.091513              0.005933              0.001168
# 2473      0.006077       0.143314              0.015227              0.003355
# 2474      0.003996       0.102772              0.010273              0.001776
#
#       % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# 0                      0.164807         0.064459           0.545882
# 1                      0.158339         0.061502           0.527843
# 2                      0.211328         0.039622           0.546667
# 3                      0.147700         0.079834           0.558824
# 4                      0.258266         0.044352           0.553725
# ...                         ...              ...                ...
# 2470                   0.282779         0.154938           0.505490
# 2471                   0.596850         0.189237           0.576078
# 2472                   0.469490         0.089296           0.590980
# 2473                   0.532909         0.366647           0.794902
# 2474                   0.424220         0.091070           0.526275
#
# [2475 rows x 13 columns]

# %%
#creating columns day,month,year for visualization purpose
br2_norm["day"]=br2_norm["Date"].dt.strftime("%d")
br2_norm["month"]=br2_norm["Date"].dt.strftime("%b")
br2_norm["year"]=br2_norm["Date"].dt.strftime("%y")

# %%
br2_norm
# Out:
#            Date  Open Price  High Price  Low Price  Close Price       WAP  \
# 0    2013-03-01    0.027338    0.028987   0.027841     0.027244  0.030878
# 1    2013-03-04    0.026331    0.023664   0.022772     0.022897  0.023817
# 2    2013-03-05    0.023309    0.024671   0.026519     0.023332  0.025720
# 3    2013-03-06    0.023022    0.028555   0.025490     0.025288  0.028343
# 4    2013-03-07    0.028777    0.027548   0.028869     0.030143  0.030434
# ...         ...         ...         ...        ...          ...       ...
# 2470 2023-02-23    0.564388    0.561605   0.560567     0.560684  0.562121
# 2471 2023-02-24    0.548417    0.565346   0.560126     0.557641  0.564021
# 2472 2023-02-27    0.543957    0.549881   0.556747     0.555902  0.555823
# 2473 2023-02-28    0.539640    0.583687   0.556821     0.589233  0.580737
# 2474 2023-03-01    0.589856    0.587139   0.594579     0.590175  0.594796
#
#       No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0         0.003787       0.039528              0.003159              0.000695
# 1         0.002465       0.039497              0.001998              0.000421
# 2         0.002022       0.027500              0.001649              0.000449
# 3         0.006693       0.062106              0.005541              0.001147
# 4         0.002906       0.026177              0.002418              0.000800
# ...            ...            ...                   ...                   ...
# 2470      0.002406       0.095635              0.006041              0.000718
# 2471      0.002122       0.036882              0.005370              0.001323
# 2472      0.002381       0.091513              0.005933              0.001168
# 2473      0.006077       0.143314              0.015227              0.003355
# 2474      0.003996       0.102772              0.010273              0.001776
#
#       % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open day month  \
# 0                      0.164807         0.064459           0.545882  01   Mar
# 1                      0.158339         0.061502           0.527843  04   Mar
# 2                      0.211328         0.039622           0.546667  05   Mar
# 3                      0.147700         0.079834           0.558824  06   Mar
# 4                      0.258266         0.044352           0.553725  07   Mar
# ...                         ...              ...                ...  ..   ...
# 2470                   0.282779         0.154938           0.505490  23   Feb
# 2471                   0.596850         0.189237           0.576078  24   Feb
# 2472                   0.469490         0.089296           0.590980  27   Feb
# 2473                   0.532909         0.366647           0.794902  28   Feb
# 2474                   0.424220         0.091070           0.526275  01   Mar
#
#      year
# 0      13
# 1      13
# 2      13
# 3      13
# 4      13
# ...   ...
# 2470   23
# 2471   23
# 2472   23
# 2473   23
# 2474   23
#
# [2475 rows x 16 columns]

# %%
plt.figure(figsize=(10, 7))
plt.plot(br2_norm['Close Price'])
plt.title('First Order Differenced Series', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Difference', fontsize=12)
plt.show()

# %%
import pandas as pd

# read in the big dataset, specifying only the columns you need
cols_to_keep = ['Date', 'Open Price', 'High Price', 'Low Price', 'Close Price', 'No.of Shares', 'WAP', 'No. of Trades', 'Total Turnover (Rs.)', 'Deliverable Quantity', '% Deli. Qty to Traded Qty', 'Spread High-Low', 'Spread Close-Open']
br2_norm = pd.read_csv(r'BERGER PAINTS.csv', usecols=cols_to_keep)

# display the original DataFrame
print('Original DataFrame:')
print(br2_norm)

# drop the 'column3' and 'column4' columns
br2_cleaned = br2_norm.drop(['WAP', 'No. of Trades', 'Total Turnover (Rs.)', 'Deliverable Quantity', '% Deli. Qty to Traded Qty', 'Spread High-Low', 'Spread Close-Open'], axis=1)

# display the updated DataFrame
print('Updated DataFrame:')
print(br2_cleaned)
# Out:
# Original DataFrame:
#                   Date  Open Price  High Price  Low Price  Close Price  \
# 0         1-March-2023      584.95      585.00     575.75       580.85
# 1     28-February-2023      550.05      582.60     550.05       580.20
# 2     27-February-2023      553.05      559.10     550.00       557.20
# 3     24-February-2023      556.15      569.85     552.30       558.40
# 4     23-February-2023      567.25      567.25     552.60       560.50
# ...                ...         ...         ...        ...          ...
# 2470      7-March-2013      195.00      196.00     190.70       194.40
# 2471      6-March-2013      191.00      196.70     188.40       191.05
# 2472      5-March-2013      191.20      194.00     189.10       189.70
# 2473      4-March-2013      193.30      193.30     186.55       189.40
# 2474      1-March-2013      194.00      197.00     190.00       192.40
#
#              WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0     581.247581         54560           3452            31712868.0
# 1     571.598180         81860           4770            46791027.0
# 2     554.498412         33372           3086            18504721.0
# 3     560.124837         29975           1310            16789742.0
# 4     558.820772         33700           3220            18832260.0
# ...          ...           ...            ...                   ...
# 2470  193.892632         40254            962             7804954.0
# 2471  192.457812         89943           2130            17310233.0
# 2472  190.657514         28661           1005             5464435.0
# 2473  189.351339         34471           1395             6527130.0
# 2474  194.197707         51814           1396            10062160.0
#
#       Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  24120.0                      44.21             9.25
# 1                  44717.0                      54.63            32.55
# 2                  16201.0                      48.55             9.10
# 3                  18213.0                      60.76            17.55
# 4                  10329.0                      30.65            14.65
# ...                    ...                        ...              ...
# 2470               11390.0                      28.30             5.30
# 2471               15923.0                      17.70             8.30
# 2472                6820.0                      23.80             4.90
# 2473                6454.0                      18.72             6.75
# 2474               10022.0                      19.34             7.00
#
#       Spread Close-Open
# 0                 -4.10
# 1                 30.15
# 2                  4.15
# 3                  2.25
# 4                 -6.75
# ...                 ...
# 2470              -0.60
# 2471               0.05
# 2472              -1.50
# 2473              -3.90
# 2474              -1.60
#
# [2475 rows x 13 columns]
# Updated DataFrame:
#                   Date  Open Price  High Price  Low Price  Close Price  \
# 0         1-March-2023      584.95      585.00     575.75       580.85
# 1     28-February-2023      550.05      582.60     550.05       580.20
# 2     27-February-2023      553.05      559.10     550.00       557.20
# 3     24-February-2023      556.15      569.85     552.30       558.40
# 4     23-February-2023      567.25      567.25     552.60       560.50
# ...                ...         ...         ...        ...          ...
# 2470      7-March-2013      195.00      196.00     190.70       194.40
# 2471      6-March-2013      191.00      196.70     188.40       191.05
# 2472      5-March-2013      191.20      194.00     189.10       189.70
# 2473      4-March-2013      193.30      193.30     186.55       189.40
# 2474      1-March-2013      194.00      197.00     190.00       192.40
#
#       No.of Shares
# 0            54560
# 1            81860
# 2            33372
# 3            29975
# 4            33700
# ...            ...
# 2470         40254
# 2471         89943
# 2472         28661
# 2473         34471
# 2474         51814
#
# [2475 rows x 6 columns]

# %%
br2_cleaned
# Out:
#                   Date  Open Price  High Price  Low Price  Close Price  \
# 0         1-March-2023      584.95      585.00     575.75       580.85
# 1     28-February-2023      550.05      582.60     550.05       580.20
# 2     27-February-2023      553.05      559.10     550.00       557.20
# 3     24-February-2023      556.15      569.85     552.30       558.40
# 4     23-February-2023      567.25      567.25     552.60       560.50
# ...                ...         ...         ...        ...          ...
# 2470      7-March-2013      195.00      196.00     190.70       194.40
# 2471      6-March-2013      191.00      196.70     188.40       191.05
# 2472      5-March-2013      191.20      194.00     189.10       189.70
# 2473      4-March-2013      193.30      193.30     186.55       189.40
# 2474      1-March-2013      194.00      197.00     190.00       192.40
#
#       No.of Shares
# 0            54560
# 1            81860
# 2            33372
# 3            29975
# 4            33700
# ...            ...
# 2470         40254
# 2471         89943
# 2472         28661
# 2473         34471
# 2474         51814
#
# [2475 rows x 6 columns]

# %%
br3_cleaned=br2_cleaned.iloc[::-1].reset_index(drop=True)
br3_cleaned
# Out:
#                   Date  Open Price  High Price  Low Price  Close Price  \
# 0         1-March-2013      194.00      197.00     190.00       192.40
# 1         4-March-2013      193.30      193.30     186.55       189.40
# 2         5-March-2013      191.20      194.00     189.10       189.70
# 3         6-March-2013      191.00      196.70     188.40       191.05
# 4         7-March-2013      195.00      196.00     190.70       194.40
# ...                ...         ...         ...        ...          ...
# 2470  23-February-2023      567.25      567.25     552.60       560.50
# 2471  24-February-2023      556.15      569.85     552.30       558.40
# 2472  27-February-2023      553.05      559.10     550.00       557.20
# 2473  28-February-2023      550.05      582.60     550.05       580.20
# 2474      1-March-2023      584.95      585.00     575.75       580.85
#
#       No.of Shares
# 0            51814
# 1            34471
# 2            28661
# 3            89943
# 4            40254
# ...            ...
# 2470         33700
# 2471         29975
# 2472         33372
# 2473         81860
# 2474         54560
#
# [2475 rows x 6 columns]

# %%
br3_cleaned["Date"]=pd.to_datetime(br3_cleaned["Date"])
br3_cleaned
# Out:
#            Date  Open Price  High Price  Low Price  Close Price  No.of Shares
# 0    2013-03-01      194.00      197.00     190.00       192.40         51814
# 1    2013-03-04      193.30      193.30     186.55       189.40         34471
# 2    2013-03-05      191.20      194.00     189.10       189.70         28661
# 3    2013-03-06      191.00      196.70     188.40       191.05         89943
# 4    2013-03-07      195.00      196.00     190.70       194.40         40254
# ...         ...         ...         ...        ...          ...           ...
# 2470 2023-02-23      567.25      567.25     552.60       560.50         33700
# 2471 2023-02-24      556.15      569.85     552.30       558.40         29975
# 2472 2023-02-27      553.05      559.10     550.00       557.20         33372
# 2473 2023-02-28      550.05      582.60     550.05       580.20         81860
# 2474 2023-03-01      584.95      585.00     575.75       580.85         54560
#
# [2475 rows x 6 columns]

# %%
#creating columns day,month,year for visualization purpose
br3_cleaned["day"]=br3_cleaned["Date"].dt.strftime("%d")
br3_cleaned["month"]=br3_cleaned["Date"].dt.strftime("%b")
br3_cleaned["year"]=br3_cleaned["Date"].dt.strftime("%y")

# %%
br3_cleaned
# Out:
#            Date  Open Price  High Price  Low Price  Close Price  No.of Shares  \
# 0    2013-03-01      194.00      197.00     190.00       192.40         51814
# 1    2013-03-04      193.30      193.30     186.55       189.40         34471
# 2    2013-03-05      191.20      194.00     189.10       189.70         28661
# 3    2013-03-06      191.00      196.70     188.40       191.05         89943
# 4    2013-03-07      195.00      196.00     190.70       194.40         40254
# ...         ...         ...         ...        ...          ...           ...
# 2470 2023-02-23      567.25      567.25     552.60       560.50         33700
# 2471 2023-02-24      556.15      569.85     552.30       558.40         29975
# 2472 2023-02-27      553.05      559.10     550.00       557.20         33372
# 2473 2023-02-28      550.05      582.60     550.05       580.20         81860
# 2474 2023-03-01      584.95      585.00     575.75       580.85         54560
#
#      day month year
# 0     01   Mar   13
# 1     04   Mar   13
# 2     05   Mar   13
# 3     06   Mar   13
# 4     07   Mar   13
# ...   ..   ...  ...
# 2470  23   Feb   23
# 2471  24   Feb   23
# 2472  27   Feb   23
# 2473  28   Feb   23
# 2474  01   Mar   23
#
# [2475 rows x 9 columns]

# %% [markdown]
# # ADF

# %%
data = {
        
        'Close': br3_cleaned['Close Price']
        }

# %%
data1 = {
        
        'Close': br1['Close Price']
        }
df1 = pd.DataFrame(data1)
df1.set_index(br1['Date'], inplace=True)
df1.dropna(inplace=True)

# %%
df = pd.DataFrame(data)
df.set_index(br1['Date'], inplace=True)
df.head()
# Out:
#                    Close
# Date
# 1-March-2023      192.40
# 28-February-2023  189.40
# 27-February-2023  189.70
# 24-February-2023  191.05
# 23-February-2023  194.40

# %%
df.dropna(inplace=True)

# %%
result = adfuller(df)
print(result)
print('ADF Test Statistic: %.2f' % result[0])
print('5%% Critical Value: %.2f' % result[4]['5%'])
print('p-value: %.2f' % result[1])
# Out:
# (-1.1478963407066822, 0.6955986168235309, 4, 2470, {'1%': -3.4330002465470844, '5%': -2.862710858596359, '10%': -2.567393294431969}, 17621.305871628727)
# ADF Test Statistic: -1.15
# 5% Critical Value: -2.86
# p-value: 0.70

# %% [markdown]
# # Arima model building

# %%
pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (2.0.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pmdarima) (0.29.28)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pmdarima) (61.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: urllib3 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pmdarima) (1.26.9)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pmdarima) (1.21.5)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: pandas>=0.19 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.19->pmdarima) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\thirumudi nachiyar\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.4)

# %%
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima

# %%
stepwise_fit = auto_arima(df1,trace=True,suppress_warnings=True)
print(stepwise_fit.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=17801.941, Time=5.97 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=17817.164, Time=0.97 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=17818.969, Time=1.26 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=17818.988, Time=1.52 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=17815.941, Time=0.95 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=17812.293, Time=3.01 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=17821.922, Time=3.77 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=17799.662, Time=5.55 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=17799.337, Time=3.95 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=17810.143, Time=2.00 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=17795.438, Time=4.73 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=17793.993, Time=2.27 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=17795.830, Time=2.73 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=17795.142, Time=7.98 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=17792.759, Time=1.59 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=17808.795, Time=1.37 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : AIC=17794.609, Time=1.46 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=17794.245, Time=2.66 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=17798.002, Time=2.09 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=17794.142, Time=3.07 sec
#
# Best model:  ARIMA(4,1,0)(0,0,0)[0]
# Total fit time: 58.920 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2475
# Model:               SARIMAX(4, 1, 0)   Log Likelihood               -8891.380
# Date:                Mon, 20 Mar 2023   AIC                          17792.759
# Time:                        12:29:48   BIC                          17821.827
# Sample:                             0   HQIC                         17803.318
#                                - 2475
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0067      0.014     -0.471      0.638      -0.034       0.021
# ar.L2          0.0602      0.019      3.241      0.001       0.024       0.097
# ar.L3          0.0462      0.016      2.825      0.005       0.014       0.078
# ar.L4         -0.0853      0.011     -8.081      0.000      -0.106      -0.065
# sigma2        77.4766      0.357    216.982      0.000      76.777      78.176
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):           1154914.75
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.65   Skew:                             4.97
# Prob(H) (two-sided):                  0.00   Kurtosis:                       108.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
train= df1[:-495]
test = df1[-495:]
print(len(train),len(test))
# Out:
# 1980 495

# %%
train.head()
# Out:
#                    Close
# Date
# 1-March-2023      580.85
# 28-February-2023  580.20
# 27-February-2023  557.20
# 24-February-2023  558.40
# 23-February-2023  560.50

# %%
model=ARIMA(train,order=(4,1,0))
model=model.fit()
model.summary()
# Out:
# C:\Users\Thirumudi Nachiyar\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Thirumudi Nachiyar\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Thirumudi Nachiyar\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Thirumudi Nachiyar\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Thirumudi Nachiyar\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Thirumudi Nachiyar\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1980
# Model:                 ARIMA(4, 1, 0)   Log Likelihood               -6991.052
# Date:                Mon, 20 Mar 2023   AIC                          13992.104
# Time:                        12:29:49   BIC                          14020.055
# Sample:                             0   HQIC                         14002.372
#                                - 1980
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0066      0.014     -0.480      0.631      -0.034       0.020
# ar.L2          0.0376      0.017      2.174      0.030       0.004       0.071
# ar.L3          0.0473      0.015      3.078      0.002       0.017       0.077
# ar.L4         -0.0448      0.016     -2.848      0.004      -0.076      -0.014
# sigma2        68.5368      0.809     84.754      0.000      66.952      70.122
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             15101.17
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.33   Skew:                             1.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                        16.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
start=len(train)
end=len(train)+len(test)-1
pred=model.predict(start=start,end=end,typ='levels')

pred.index=df.index[start:end+1]
print(pred)
# Out:
# Date
# 4-March-2015        212.740604
# 3-March-2015        213.082316
# 2-March-2015        213.164086
# 28-February-2015    213.023974
# 27-February-2015    213.040090
#                        ...
# 7-March-2013        213.019218
# 6-March-2013        213.019218
# 5-March-2013        213.019218
# 4-March-2013        213.019218
# 1-March-2013        213.019218
# Name: predicted_mean, Length: 495, dtype: float64
# C:\Users\Thirumudi Nachiyar\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
pred.plot(legend=True)
test['Close'].plot(legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# mean squre error to campere predicted value and acule value
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(test,pred))
# Out:
# 78.02086562210062

# %% [markdown]
# # mean squre error is very high to campare to mean value thais it not mack any sance to go to future prediction

# %%
from sklearn.metrics import r2_score
r2_score(test,pred)
# Out:
# -0.49433420596818634

# %%
test.describe()
# Out:
#             Close
# count  495.000000
# mean   257.893535
# std     63.888990
# min    185.800000
# 25%    216.450000
# 50%    231.100000
# 75%    288.000000
# max    452.250000

# %% [markdown]
# # Sarima Model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error

# %%
# Split the data into training and testing sets
train= df1[:-495]
test = df1[-495:]
print(len(train),len(test))
# Out:
# 1980 495

# %%
train
# Out:
#                    Close
# Date
# 1-March-2023      580.85
# 28-February-2023  580.20
# 27-February-2023  557.20
# 24-February-2023  558.40
# 23-February-2023  560.50
# ...                  ...
# 12-March-2015     213.75
# 11-March-2015     209.95
# 10-March-2015     207.25
# 9-March-2015      209.15
# 5-March-2015      212.65
#
# [1980 rows x 1 columns]

# %%
test
# Out:
#                    Close
# Date
# 4-March-2015      216.40
# 3-March-2015      223.50
# 2-March-2015      223.20
# 28-February-2015  223.70
# 27-February-2015  225.85
# ...                  ...
# 7-March-2013      194.40
# 6-March-2013      191.05
# 5-March-2013      189.70
# 4-March-2013      189.40
# 1-March-2013      192.40
#
# [495 rows x 1 columns]

# %%
# Visualize the time series
plt.plot(train['Close'])
plt.title('Stock Market Data')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.show()

# %%
# Define the SARIMA model parameters
order = (2, 1, 1)
seasonal_order = (1, 1, 1, 12)

# %%
order
# Out:
# (2, 1, 1)

# %%
seasonal_order
# Out:
# (1, 1, 1, 12)

# %%
# Fit a SARIMAX model
import statsmodels.api as sm
model = sm.tsa.SARIMAX(test, order=(1, 0, 1), seasonal_order=(0, 0, 0, 0))
results = model.fit()
results.summary()
# Out:
# C:\Users\Thirumudi Nachiyar\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Thirumudi Nachiyar\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Thirumudi Nachiyar\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Thirumudi Nachiyar\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  495
# Model:               SARIMAX(1, 0, 1)   Log Likelihood               -1883.437
# Date:                Mon, 20 Mar 2023   AIC                           3772.874
# Time:                        12:39:21   BIC                           3785.488
# Sample:                             0   HQIC                          3777.826
#                                 - 495
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9990      0.002    434.081      0.000       0.994       1.004
# ma.L1         -0.0101      0.058     -0.174      0.862      -0.124       0.104
# sigma2       116.6795      1.037    112.498      0.000     114.647     118.712
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            957292.58
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.07   Skew:                            11.53
# Prob(H) (two-sided):                  0.00   Kurtosis:                       217.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
results.params
# Out:
# ar.L1       0.999005
# ma.L1      -0.010107
# sigma2    116.679547
# dtype: float64

# %%
# Make predictions
predictions = results.predict()

# %%
# Display the predictions
print(predictions)
# Out:
# Date
# 4-March-2015          0.000000
# 3-March-2015        216.180278
# 2-March-2015        223.203681
# 28-February-2015    222.977989
# 27-February-2015    223.470157
#                        ...
# 7-March-2013        201.350685
# 6-March-2013        194.276855
# 5-March-2013        190.892550
# 4-March-2013        189.523333
# 1-March-2013        189.212824
# Name: predicted_mean, Length: 495, dtype: float64

# %%
predictions.plot(legend=True)
test['Close'].plot(legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>
